# %%
import pandas as pd
import pyarrow.parquet as pq
import os
import numpy as np
import matplotlib.pyplot as plt
import random
from scipy.fftpack import fft, ifft
import scipy.integrate as integrate

from tqdm import trange
import gc
import seaborn as sns
from tqdm import tqdm

from sklearn.feature_extraction.text import CountVectorizer
import re
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn import metrics
from scipy import fftpack

from bokeh.plotting import figure,show,output_file, ColumnDataSource
from bokeh.io import push_notebook, output_notebook
from bokeh.layouts import column

from sklearn.model_selection import KFold
import lightgbm as lgb

import peakutils

from numpy.fft import rfft, rfftfreq, irfft
from sklearn.metrics import matthews_corrcoef as mcc


output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1003">Loading BokehJS ...</span>
#     </div>

# %%
# %%time
meta_train = pd.read_csv('input/metadata_train.csv')
raw_train = pq.read_pandas('input/train.parquet').to_pandas()
# Out:
# CPU times: user 1min 50s, sys: 48.1 s, total: 2min 38s
# Wall time: 43.9 s

# %%
R = 0.02 #range of data sample in seconds
N_measurements = 8e5 #number of measurements in one cycle
D_0 = R/N_measurements #how often the signal is sampled


print('Sampling delta: {} ns'.format(D_0 * 1e9))
print('Sampling frequency: {} MHz'.format(1/(D_0 * 1e6)))
print('\n')
print('Nyquist frequency (f_max): {} MHz'.format(1/(D_0 * 1e6)/2))
print('Min frequency (f_min and also minimum discernible frequency gap): {} Hz'.format(1/R))
# Out:
# Sampling delta: 25.0 ns
# Sampling frequency: 40.0 MHz
#
#
# Nyquist frequency (f_max): 20.0 MHz
# Min frequency (f_min and also minimum discernible frequency gap): 50.0 Hz

# %%
def fft_peaks(time_series, buckets = 100, stdevs = 0.7):
    FFT = abs(fftpack.fft(time_series))
    FFT[FFT < FFT.std() * stdevs] = 0
    
    freq_range = FFT.shape[0]//2
    buck_size = int(np.ceil((freq_range)/(buckets)))
    
    segments = [(i,i+buck_size) for i in range(0, freq_range, buck_size)]
    fft_components = [np.sum(FFT[ind_[0]:ind_[1]]) for ind_ in segments]
    fft_ranges = [(int(ind_[0]*5e-2), int(ind_[1]*5e-2)) for ind_ in segments]
    
    return fft_components, fft_ranges

# %%
def generate_fourier_dataset(train_set, meta_train, buckets):
    train_length = meta_train.shape[0]
    positive_length = len(meta_train[meta_train.target == 1])
    hand_features = ['mean','max','min','std']
    
    dataset = np.zeros((train_length, len(hand_features) + buckets + 1))
    imbalance_ = positive_length / train_length
    
    row_index = 0
    for i in trange(train_length):
        if meta_train.loc[i, 'target'] == 1 or (random.random() < imbalance_):
            spectrum = train_set[str(i)]
            
            fft_integrals, fft_ranges = fft_peaks(spectrum, buckets)
            
            features_temp = np.array([spectrum.mean(), spectrum.max(), spectrum.min(), spectrum.std()] 
                                + fft_integrals)
            
            label_temp = meta_train.loc[i, 'target']
            dataset[row_index,:] = np.concatenate([features_temp, [label_temp]])
            
            row_index += 1
    
    
    #discard zeros
    tmp_ = np.sum(dataset, axis=1)
    nzv = len(tmp_[tmp_ != 0])
    
    return pd.DataFrame(columns= hand_features + ['ft_' + str(ran[1]) + str('GHz') for ran in fft_ranges] + ['label'], 
                        data = dataset[0:nzv,:])

# %%
def generate_fourier_dataset_test(test_set, meta_test, buckets):
    test_length = meta_test.shape[0]
    hand_features = ['mean','max','min','std']
    
    dataset = np.zeros((test_length, len(hand_features) + buckets))
    
    row_index = 0
    for i in trange(test_length):
        spectrum = test_set[str(i + 8712)]

        fft_integrals, fft_ranges = fft_peaks(spectrum, buckets)

        features_temp = np.array([spectrum.mean(), spectrum.max(), spectrum.min(), spectrum.std()] 
                            + fft_integrals)

        dataset[row_index,:] = features_temp

        row_index += 1
        
    return pd.DataFrame(columns= hand_features + ['ft_' + str(ran[1]) + str('GHz') for ran in fft_ranges], 
                        data = dataset)

# %%
# %%time
train = generate_fourier_dataset(raw_train, meta_train, 60)


print('Train length: {}'.format(len(train)))
print('Positive length: {}'.format(len(train[train.label == 1])))
# Out:
# 100%|██████████| 8712/8712 [01:05<00:00, 132.88it/s]
# Train length: 1070
# Positive length: 525
# CPU times: user 58.2 s, sys: 5.05 s, total: 1min 3s
# Wall time: 1min 5s

# %%
def my_err_rate(y_hat, dtrain):
    y = dtrain.get_label()
    y_hat = np.round(y_hat)
    MCC = mcc(y, y_hat)
    return 'MCC', MCC, True

# %%
x_train = train.copy()
target = x_train['label']
input_target = x_train['label']
x_train.drop(['label'], axis=1, inplace=True)
features = x_train.columns
param = {'num_leaves': 120,
         'min_data_in_leaf': 80, 
         'objective':'binary',
         'max_depth': -1,
         'learning_rate': 0.05,
         "boosting": "gbdt",
         "feature_fraction": 0.8,
         "bagging_freq": 2,
         "bagging_fraction": 0.8 ,
         "bagging_seed": 11,
         "metric": 'auc',
         "lambda_l1": 0.1,
         "random_state": 164,
         "verbosity": -1}
max_iter=5

# %%
folds = KFold(n_splits=5, shuffle=True, random_state=19)
oof = np.zeros(len(x_train))
feature_importance_df = pd.DataFrame()
score = [0 for _ in range(folds.n_splits)]

for fold_, (trn_idx, val_idx) in enumerate(folds.split(x_train.values, target.values)):
    print("Fold No.{}".format(fold_+1))
    trn_data = lgb.Dataset(x_train.iloc[trn_idx][features],
                           label=target.iloc[trn_idx])
    val_data = lgb.Dataset(x_train.iloc[val_idx][features],
                           label=target.iloc[val_idx])
    num_round = 15000
    clf = lgb.train(param,
                    trn_data,
                    num_round,
                    valid_sets = [trn_data, val_data],
                    feval = my_err_rate,
                    verbose_eval=100,
                    early_stopping_rounds = 300)
    
    oof[val_idx] = clf.predict(x_train.iloc[val_idx][features], num_iteration=clf.best_iteration)
    fold_importance_df = pd.DataFrame()
    fold_importance_df["feature"] = features
    fold_importance_df["importance"] = clf.feature_importance(importance_type='gain')
    fold_importance_df["fold"] = fold_ + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    score[fold_] = metrics.roc_auc_score(target.iloc[val_idx], oof[val_idx])
    if fold_ == max_iter - 1: break
        

if (folds.n_splits == max_iter):
    print("CV score: {:<8.5f}".format(metrics.roc_auc_score(target, oof)))
    print("MCC score: {:<8.5f}".format(mcc(target, np.round(oof))))
else:
     print("CV score: {:<8.5f}".format(sum(score) / max_iter))
# Out:
# Fold No.1
# Training until validation scores don't improve for 300 rounds.
# [100]	training's auc: 0.968313	training's MCC: 0.8031	valid_1's auc: 0.947297	valid_1's MCC: 0.781302
# [200]	training's auc: 0.990233	training's MCC: 0.893024	valid_1's auc: 0.954876	valid_1's MCC: 0.7421
# [300]	training's auc: 0.996561	training's MCC: 0.941719	valid_1's auc: 0.956103	valid_1's MCC: 0.74066
# Early stopping, best iteration is:
# [60]	training's auc: 0.951858	training's MCC: 0.741123	valid_1's auc: 0.942741	valid_1's MCC: 0.783315
# Fold No.2
# Training until validation scores don't improve for 300 rounds.
# [100]	training's auc: 0.968161	training's MCC: 0.791635	valid_1's auc: 0.95	valid_1's MCC: 0.747564
# [200]	training's auc: 0.988782	training's MCC: 0.888192	valid_1's auc: 0.958304	valid_1's MCC: 0.785355
# [300]	training's auc: 0.996514	training's MCC: 0.932339	valid_1's auc: 0.959878	valid_1's MCC: 0.804719
# [400]	training's auc: 0.999339	training's MCC: 0.974305	valid_1's auc: 0.960315	valid_1's MCC: 0.795002
# [500]	training's auc: 0.999956	training's MCC: 0.990658	valid_1's auc: 0.959703	valid_1's MCC: 0.784968
# Early stopping, best iteration is:
# [221]	training's auc: 0.990853	training's MCC: 0.899816	valid_1's auc: 0.960402	valid_1's MCC: 0.81451
# Fold No.3
# Training until validation scores don't improve for 300 rounds.
# [100]	training's auc: 0.97156	training's MCC: 0.817504	valid_1's auc: 0.914336	valid_1's MCC: 0.64504
# [200]	training's auc: 0.991285	training's MCC: 0.907034	valid_1's auc: 0.917133	valid_1's MCC: 0.654707
# [300]	training's auc: 0.99723	training's MCC: 0.958096	valid_1's auc: 0.919755	valid_1's MCC: 0.682138
# [400]	training's auc: 0.999033	training's MCC: 0.976663	valid_1's auc: 0.921503	valid_1's MCC: 0.692269
# [500]	training's auc: 0.999852	training's MCC: 0.992986	valid_1's auc: 0.923339	valid_1's MCC: 0.692269
# [600]	training's auc: 0.999989	training's MCC: 0.995323	valid_1's auc: 0.925437	valid_1's MCC: 0.720102
# [700]	training's auc: 1	training's MCC: 1	valid_1's auc: 0.923689	valid_1's MCC: 0.729203
# [800]	training's auc: 1	training's MCC: 1	valid_1's auc: 0.924563	valid_1's MCC: 0.710451
# [900]	training's auc: 1	training's MCC: 1	valid_1's auc: 0.924038	valid_1's MCC: 0.719616
# Early stopping, best iteration is:
# [602]	training's auc: 0.999989	training's MCC: 0.997664	valid_1's auc: 0.925962	valid_1's MCC: 0.720102
# Fold No.4
# Training until validation scores don't improve for 300 rounds.
# [100]	training's auc: 0.971849	training's MCC: 0.802277	valid_1's auc: 0.913811	valid_1's MCC: 0.664449
# [200]	training's auc: 0.991034	training's MCC: 0.902702	valid_1's auc: 0.923689	valid_1's MCC: 0.719384
# [300]	training's auc: 0.997437	training's MCC: 0.951041	valid_1's auc: 0.921941	valid_1's MCC: 0.719616
# [400]	training's auc: 0.999601	training's MCC: 0.97428	valid_1's auc: 0.922465	valid_1's MCC: 0.710104
# [500]	training's auc: 0.999973	training's MCC: 0.995323	valid_1's auc: 0.921591	valid_1's MCC: 0.719384
# Early stopping, best iteration is:
# [208]	training's auc: 0.991919	training's MCC: 0.898027	valid_1's auc: 0.924738	valid_1's MCC: 0.728833
# Fold No.5
# Training until validation scores don't improve for 300 rounds.
# [100]	training's auc: 0.972365	training's MCC: 0.806801	valid_1's auc: 0.913564	valid_1's MCC: 0.691038
# [200]	training's auc: 0.989939	training's MCC: 0.895533	valid_1's auc: 0.923227	valid_1's MCC: 0.728715
# [300]	training's auc: 0.996943	training's MCC: 0.939406	valid_1's auc: 0.927394	valid_1's MCC: 0.731516
# [400]	training's auc: 0.999361	training's MCC: 0.978974	valid_1's auc: 0.928723	valid_1's MCC: 0.769219
# [500]	training's auc: 0.999934	training's MCC: 0.995327	valid_1's auc: 0.929787	valid_1's MCC: 0.758349
# [600]	training's auc: 1	training's MCC: 0.997666	valid_1's auc: 0.931383	valid_1's MCC: 0.755663
# [700]	training's auc: 1	training's MCC: 0.997666	valid_1's auc: 0.929433	valid_1's MCC: 0.777194
# Early stopping, best iteration is:
# [433]	training's auc: 0.99964	training's MCC: 0.983646	valid_1's auc: 0.928635	valid_1's MCC: 0.777194
# CV score: 0.93078
# MCC score: 0.76249

# %%
cols = (feature_importance_df[["feature", "importance"]]
        .groupby("feature")
        .mean()
        .sort_values(by="importance", ascending=False)[:1000].index)
best_features = feature_importance_df.loc[feature_importance_df.feature.isin(cols)]

plt.figure(figsize=(10,10))
sns.barplot(x="importance",
            y="feature",
            data=best_features.sort_values(by="importance",ascending=False))
plt.title('LightGBM Features (avg over folds)')
plt.tight_layout()

# %%
gc.collect()
# Out:
# 25855

# %% [markdown]
# # Predict and Submit

# %%
# %%time
meta_test = pd.read_csv('input/metadata_test.csv')
# Out:
# CPU times: user 8.81 ms, sys: 4.44 ms, total: 13.2 ms
# Wall time: 13.2 ms

# %%
# %%time
meta_test = pd.read_csv('input/metadata_test.csv')
subset_test = pq.read_pandas('input/test.parquet').to_pandas()
# Out:
# CPU times: user 4min 32s, sys: 2min 10s, total: 6min 42s
# Wall time: 2min 13s

# %%
# %%time
test = generate_fourier_dataset_test(subset_test, meta_test, 60)
print('Train length: {}'.format(len(test)))
# Out:
# 100%|██████████| 20337/20337 [22:18<00:00, 15.56it/s]
# Train length: 20337
# CPU times: user 19min 22s, sys: 2min 17s, total: 21min 39s
# Wall time: 22min 18s

# %%
test.shape
# Out:
# (20337, 64)

# %%
test.to_csv("test.csv", index=False)

# %%
x_filename = meta_test.signal_id
predictions = clf.predict(test, num_iteration=clf.best_iteration)

# %%
sub_df = pd.DataFrame({"signal_id":x_filename.values})
sub_df["target"] = pd.Series(predictions).round()
sub_df['signal_id'] = sub_df['signal_id'].astype(np.int64)
sub_df['target'] = sub_df['target'].astype(np.int64)
sub_df.to_csv("submission_four.csv", index=False)
sub_df

# %%
positive = len(sub_df[sub_df["target"] == 1])
print('Predicted positive: {}. {}% of total.'.format(positive, positive/len(sub_df)*100))

# %%
x_test = test
x_filename = x_test['signal_id']
x_test = x_test.drop('signal_id', axis=1)

predictions = clf.predict(x_test, num_iteration=clf.best_iteration)

sub_df = pd.DataFrame({"signal_id":x_filename.values})
sub_df["target"] = pd.Series(predictions).round()
sub_df['signal_id'] = sub_df['signal_id'].astype(np.int64)
sub_df['target'] = sub_df['target'].astype(np.int64)
sub_df.to_csv("submission_three.csv", index=False)
sub_df
# Out:
#        signal_id  target
# 0           8712       0
# 1           8713       0
# 2           8714       0
# 3           8715       0
# 4           8716       0
# 5           8717       0
# 6           8718       0
# 7           8719       0
# 8           8720       0
# 9           8721       0
# 10          8722       0
# 11          8723       0
# 12          8724       0
# 13          8725       0
# 14          8726       0
# 15          8727       0
# 16          8728       0
# 17          8729       0
# 18          8730       0
# 19          8731       0
# 20          8732       0
# 21          8733       0
# 22          8734       0
# 23          8735       0
# 24          8736       0
# 25          8737       0
# 26          8738       0
# 27          8739       0
# 28          8740       0
# 29          8741       0
# ...          ...     ...
# 20307      29019       0
# 20308      29020       0
# 20309      29021       0
# 20310      29022       0
# 20311      29023       0
# 20312      29024       0
# 20313      29025       0
# 20314      29026       0
# 20315      29027       0
# 20316      29028       0
# 20317      29029       0
# 20318      29030       0
# 20319      29031       0
# 20320      29032       0
# 20321      29033       0
# 20322      29034       0
# 20323      29035       1
# 20324      29036       0
# 20325      29037       0
# 20326      29038       0
# 20327      29039       0
# 20328      29040       0
# 20329      29041       0
# 20330      29042       0
# 20331      29043       0
# 20332      29044       0
# 20333      29045       0
# 20334      29046       0
# 20335      29047       0
# 20336      29048       0
#
# [20337 rows x 2 columns]

# %%
positive = len(sub_df[sub_df["target"] == 1])
print(positive)
print(str(positive/len(sub_df)*100) + "%")
# Out:
# 129
# 0.6343118454049269%

# %% [markdown]
# # Demonstrations

# %%
meta_ = meta_train
dataset = subset_train

# %%
def show_shit(num_ = None):
    if not num_:
        num_ = np.random.randint(0,dataset.shape[0])
    print('Plot number: {}. Condition: {}'.format(num_, meta_.target.iloc[num_]))
    plt.figure(figsize=(15, 6))
    slic = dataset[str(num_)]
    plt.plot(slic, label='Phase 0')
    print('Max: {}, min: {}, std deviation: {}, agv: {}'.format(slic.max(), slic.min(), slic.std(), slic.mean()))
    plt.legend()
    plt.show()

# %%
for item in meta_[meta_.target==1].signal_id.tolist():
    print(item, end = ' ')
# Out:
# 3 4 5 201 202 228 229 230 270 271 272 279 280 281 285 286 287 290 294 295 296 380 408 409 410 432 433 434 435 436 437 456 457 458 479 516 517 518 570 571 572 678 679 680 699 700 701 705 706 707 708 709 710 813 876 877 878 903 912 913 914 939 940 941 1002 1003 1004 1017 1018 1019 1026 1027 1028 1032 1033 1034 1050 1051 1052 1074 1075 1076 1083 1084 1085 1134 1135 1136 1263 1264 1265 1331 1335 1336 1337 1434 1435 1436 1449 1450 1451 1455 1456 1457 1554 1575 1576 1577 1737 1738 1739 1803 1805 1824 1826 1860 1862 1884 1885 1886 1899 1900 1901 1992 1993 1994 2085 2086 2087 2097 2098 2099 2115 2116 2117 2118 2119 2139 2140 2141 2160 2161 2162 2169 2170 2171 2193 2194 2195 2277 2278 2279 2307 2308 2309 2322 2323 2324 2343 2344 2345 2352 2353 2354 2418 2419 2420 2514 2515 2516 2628 2629 2630 2640 2641 2642 2682 2833 2834 2904 2905 2906 2952 2953 2954 2965 2966 2985 2986 2987 3030 3031 3032 3204 3206 3228 3229 3237 3238 3239 3243 3244 3245 3275 3309 3310 3311 3345 3346 3347 3372 3373 3374 3396 3519 3520 3521 3534 3535 3536 3570 3571 3572 3612 3613 3614 3768 3770 3806 3831 3912 3914 3978 3979 3980 4035 4036 4037 4053 4054 4055 4068 4069 4070 4086 4087 4088 4125 4126 4127 4143 4144 4145 4158 4159 4160 4164 4165 4166 4212 4213 4214 4221 4222 4223 4224 4225 4226 4233 4234 4235 4239 4240 4241 4248 4249 4250 4257 4258 4259 4262 4332 4333 4334 4350 4351 4352 4353 4354 4355 4548 4549 4550 4578 4579 4580 4596 4597 4598 4611 4613 4632 4633 4634 4685 4692 4693 4694 4713 4714 4715 4737 4738 4739 4767 4768 4769 4815 4816 4817 4836 4837 4838 4872 4873 4874 4932 4933 4934 4938 4939 4940 5004 5006 5007 5008 5009 5016 5017 5018 5019 5020 5021 5061 5062 5063 5112 5113 5181 5182 5183 5196 5197 5198 5250 5251 5252 5283 5284 5285 5307 5308 5309 5316 5317 5318 5364 5365 5366 5367 5368 5369 5487 5488 5489 5541 5542 5543 5654 5699 5730 5731 5732 5943 5944 5945 5983 6228 6229 6230 6243 6244 6245 6276 6277 6278 6282 6283 6284 6303 6304 6305 6351 6352 6353 6378 6379 6380 6501 6502 6503 6525 6526 6527 6636 6637 6638 6639 6640 6641 6654 6655 6656 6672 6673 6674 6690 6691 6692 6744 6745 6746 6759 6760 6761 6822 6823 6824 6942 6943 6944 6966 6967 6968 6984 6986 7005 7006 7007 7020 7021 7022 7119 7120 7121 7308 7309 7310 7467 7468 7469 7482 7483 7484 7512 7513 7514 7620 7621 7622 7644 7645 7646 7725 7726 7727 7773 7774 7775 7791 7792 7793 7869 7870 7917 7918 7919 7923 7924 7925 7947 7948 7949 8019 8020 8021 8031 8032 8033 8061 8062 8063 8079 8081 8205 8206 8207 8261 8280 8281 8289 8290 8291 8422 8423 8433 8434 8435 8481 8482 8483 8568 8569 8570 8630

# %%
show_shit(num_=4160)
# Out:
# Plot number: 4160. Condition: 1
# Max: 127, min: -125, std deviation: 13.510575146725843, agv: -0.049065
